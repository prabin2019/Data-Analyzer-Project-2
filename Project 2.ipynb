# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dt= pd.read_csv('Most-Recent-Cohorts-All-Data-Elements.csv')

# %%
dt
# Out:
#         UNITID    OPEID  OPEID6  \
# 0       100654   100200    1002
# 1       100663   105200    1052
# 2       100690  2503400   25034
# 3       100706   105500    1055
# 4       100724   100500    1005
# 5       100751   105100    1051
# 6       100760   100700    1007
# 7       100812   100800    1008
# 8       100830   831000    8310
# 9       100858   100900    1009
# 10      100937   101200    1012
# 11      101028  1218200   12182
# 12      101073  1055400   10554
# 13      101116  1303906   13039
# 14      101143   101500    1015
# 15      101161   106000    1060
# 16      101189   100300    1003
# 17      101240   101700    1017
# 18      101277  4187200   41872
# 19      101286   101800    1018
# 20      101295   787100    7871
# 21      101301   569900    5699
# 22      101365   962107    9621
# 23      101435   101900    1019
# 24      101453  2199700   21997
# 25      101462   526000    5260
# 26      101471  3002500   30025
# 27      101480   102000    1020
# ...

# %%
dt.shape
# Out:
# (7058, 1977)

# %%
dt.dtypes
# Out:
# UNITID                                int64
# OPEID                                 int64
# OPEID6                                int64
# INSTNM                               object
# CITY                                 object
# STABBR                               object
# ZIP                                  object
# ACCREDAGENCY                         object
# INSTURL                              object
# NPCURL                               object
# SCH_DEG                             float64
# HCM2                                  int64
# MAIN                                  int64
# NUMBRANCH                             int64
# PREDDEG                               int64
# HIGHDEG                               int64
# CONTROL                               int64
# ST_FIPS                               int64
# REGION                                int64
# LOCALE                              float64
# LOCALE2                             float64
# ...

# %%
dt.columns
# Out:
# Index(['UNITID', 'OPEID', 'OPEID6', 'INSTNM', 'CITY', 'STABBR', 'ZIP',
#        'ACCREDAGENCY', 'INSTURL', 'NPCURL',
#        ...
#        'OMAWDP8_NOTFIRSTTIME_POOLED_SUPP', 'OMENRUP_NOTFIRSTTIME_POOLED_SUPP',
#        'OMENRYP_FULLTIME_POOLED_SUPP', 'OMENRAP_FULLTIME_POOLED_SUPP',
#        'OMAWDP8_FULLTIME_POOLED_SUPP', 'OMENRUP_FULLTIME_POOLED_SUPP',
#        'OMENRYP_PARTTIME_POOLED_SUPP', 'OMENRAP_PARTTIME_POOLED_SUPP',
#        'OMAWDP8_PARTTIME_POOLED_SUPP', 'OMENRUP_PARTTIME_POOLED_SUPP'],
#       dtype='object', length=1977)

# %%
print(dt.columns.values)
# Out:
# ['UNITID' 'OPEID' 'OPEID6' ... 'OMENRAP_PARTTIME_POOLED_SUPP'
#  'OMAWDP8_PARTTIME_POOLED_SUPP' 'OMENRUP_PARTTIME_POOLED_SUPP']

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7058 entries, 0 to 7057
# Columns: 1977 entries, UNITID to OMENRUP_PARTTIME_POOLED_SUPP
# dtypes: float64(617), int64(14), object(1346)
# memory usage: 106.5+ MB

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['ACCREDAGENCY', 'INSTURL', 'NPCURL', 'SCH_DEG', 'LOCALE', 'LOCALE2',
#        'LATITUDE', 'LONGITUDE', 'CCBASIC', 'CCUGPROF',
#        ...
#        'OMAWDP8_NOTFIRSTTIME_POOLED_SUPP', 'OMENRUP_NOTFIRSTTIME_POOLED_SUPP',
#        'OMENRYP_FULLTIME_POOLED_SUPP', 'OMENRAP_FULLTIME_POOLED_SUPP',
#        'OMAWDP8_FULLTIME_POOLED_SUPP', 'OMENRUP_FULLTIME_POOLED_SUPP',
#        'OMENRYP_PARTTIME_POOLED_SUPP', 'OMENRAP_PARTTIME_POOLED_SUPP',
#        'OMAWDP8_PARTTIME_POOLED_SUPP', 'OMENRUP_PARTTIME_POOLED_SUPP'],
#       dtype='object', length=1958)

# %%
dt.groupby
# Out:
# <bound method NDFrame.groupby of         UNITID    OPEID  OPEID6  \
# 0       100654   100200    1002
# 1       100663   105200    1052
# 2       100690  2503400   25034
# 3       100706   105500    1055
# 4       100724   100500    1005
# 5       100751   105100    1051
# 6       100760   100700    1007
# 7       100812   100800    1008
# 8       100830   831000    8310
# 9       100858   100900    1009
# 10      100937   101200    1012
# 11      101028  1218200   12182
# 12      101073  1055400   10554
# 13      101116  1303906   13039
# 14      101143   101500    1015
# 15      101161   106000    1060
# 16      101189   100300    1003
# 17      101240   101700    1017
# 18      101277  4187200   41872
# 19      101286   101800    1018
# 20      101295   787100    7871
# 21      101301   569900    5699
# 22      101365   962107    9621
# 23      101435   101900    1019
# 24      101453  2199700   21997
# 25      101462   526000    5260
# 26      101471  3002500   30025
# ...

# %% [markdown]
# # 1) What is the most costly college? What is the cheapest?

# %%
df['COSTT4_A']
# Out:
# 0       22886.0
# 1       24129.0
# 2       15080.0
# 3       22108.0
# 4       19413.0
# 5       28836.0
# 6       10045.0
# 7           NaN
# 8       19892.0
# 9       30458.0
# 10      50400.0
# 11       6854.0
# 12      27620.0
# 13      26613.0
# 14       9289.0
# 15      12558.0
# 16      31720.0
# 17       9701.0
# 18          NaN
# 19       9298.0
# 20      11408.0
# 21      14571.0
# 22      27797.0
# 23      34675.0
# 24          NaN
# 25      11514.0
# 26       5496.0
# 27      20890.0
# 28      11677.0
# 29      13017.0
#          ...
# 7028        NaN
# 7029        NaN
# 7030        NaN
# 7031        NaN
# 7032        NaN
# 7033        NaN
# 7034        NaN
# 7035        NaN
# 7036        NaN
# 7037        NaN
# 7038        NaN
# 7039        NaN
# 7040        NaN
# 7041        NaN
# 7042        NaN
# 7043        NaN
# 7044        NaN
# 7045        NaN
# 7046        NaN
# 7047        NaN
# 7048        NaN
# 7049        NaN
# 7050        NaN
# 7051        NaN
# ...

# %%
# combining program and annual cost together 
dt['COST'] = dt['COSTT4_A']
dt['COST'] = dt['COST'].fillna(dt['COSTT4_P'])

# %%
print ('The most cost college is:',dt.loc[dt['COST'].idxmax()].INSTNM)
print ('For the cost of :',dt.loc[dt['COST'].idxmax()].COST)
# Out:
# The most costly college is: L3 Commercial Training Solutions Airline Academy
# For the cost of : 105745.0

# %%
# Out:
# <bound method Series.max of 0       22886.0
# 1       24129.0
# 2       15080.0
# 3       22108.0
# 4       19413.0
# 5       28836.0
# 6       10045.0
# 7           NaN
# 8       19892.0
# 9       30458.0
# 10      50400.0
# 11       6854.0
# 12      27620.0
# 13      26613.0
# 14       9289.0
# 15      12558.0
# 16      31720.0
# 17       9701.0
# 18          NaN
# 19       9298.0
# 20      11408.0
# 21      14571.0
# 22      27797.0
# 23      34675.0
# 24          NaN
# 25      11514.0
# 26       5496.0
# 27      20890.0
# 28      11677.0
# 29      13017.0
#          ...
# 7028        NaN
# 7029        NaN
# 7030        NaN
# 7031        NaN
# 7032        NaN
# 7033        NaN
# 7034        NaN
# 7035        NaN
# 7036        NaN
# 7037        NaN
# 7038        NaN
# 7039        NaN
# 7040        NaN
# 7041        NaN
# 7042        NaN
# 7043        NaN
# 7044        NaN
# 7045        NaN
# 7046        NaN
# 7047        NaN
# 7048        NaN
# 7049        NaN
# 7050        NaN
# ...

# %%
print ( 'The most cheap college is:',dt.loc[dt['COST'].idxmin()].INSTNM)
# Out:
# The most cheapest college is: Purdue University Northwest

# %% [markdown]
# #  2) What is the average cost for college for colleges in different parts of the US?

# %%
# Creating a data frame named AVgCost
# Dropping the row Named COST.
AvgCost = dt.dropna(subset=['COST'])
AvgCost = round(AvgCost.groupby(['STABBR'])['COST'].mean())

# %%
print (AvgCost.sort_values(ascending=False))
# Out:
# STABBR
# VT    39869.0
# DC    36921.0
# MA    35063.0
# RI    34898.0
# PA    29007.0
# NH    28653.0
# ME    28091.0
# NY    27910.0
# IN    26988.0
# CT    26631.0
# IA    25968.0
# MD    25329.0
# CA    25254.0
# VA    25170.0
# NJ    25149.0
# MN    24887.0
# WI    24553.0
# DE    24394.0
# NE    24390.0
# SC    24323.0
# OR    23797.0
# FL    23676.0
# GA    23428.0
# OH    23277.0
# IL    23245.0
# CO    23154.0
# NC    22907.0
# TN    22750.0
# MI    22736.0
# NV    22694.0
# MO    22621.0
# KY    22480.0
# WA    22177.0
# KS    21793.0
# TX    21573.0
# AZ    21327.0
# SD    21214.0
# LA    20874.0
# HI    20745.0
# AL    20662.0
# AK    20203.0
# UT    20058.0
# ID    19609.0
# MS    19143.0
# AR    18277.0
# WV    18102.0
# NM    18100.0
# OK    17511.0
# ND    17174.0
# MT    17120.0
# VI    16786.0
# WY    14714.0
# GU    12339.0
# PR    11653.0
# FM     9554.0
# MH     8750.0
# MP     8734.0
# AS     7400.0
# PW     6085.0
# Name: COST, dtype: float64

# %% [markdown]
# # 3) What is the average cost for college for religious vs. secular institutions?

# %%
# Creating a new dataframe Recost for the cost of Religious instutions and droppig the rows with  missing value.
ReCost = dt.dropna(subset=['RELAFFIL'])

# %%
print ( 'The average cost for religious college  is = ' ,round(ReCost.COST.mean()))
# Out:
# The average cost for religious college  is =  37389

# %%
# Creating a new dataframe SeCost for the cost of secular instutions
# dropping the column where secular is Nan.
seCost = dt.loc[pd.isnull(dt).any(1),:]
print ( 'The average cost for Secular college  is = ' , round(SeCost.COST.mean()))
# Out:
# The average cost for Secular college  is =  37389

# %% [markdown]
#  # 4) What percent of colleges have an open admission policy?

# %%
# create a data frame with only open addmission schools:
# drop rows with NaN value
openAd = dt.dropna(subset=['OPENADMP'])
#dropping rows with non-open admision
openAd = openAd[openAd.OPENADMP !=2]
# calculating the percentage of open admission out of all schools
print('There are', len(openAd), 'schools with open admission','which make', round((len(openAd))/(len(dt))*100),
 '% of all', len(dt), 'schools')
# Out:
# There are 4063 schools with open admission which make 58 % of all 7058 schools

# %% [markdown]
# # Q5) What is the correlation (scatterplot) between admission rates and college cost?

# %%
df['ADM_RATE'].head(10)
# Out:
# 0    0.9027
# 1    0.9181
# 2       NaN
# 3    0.8123
# 4    0.9787
# 5    0.5330
# 6       NaN
# 7       NaN
# 8    0.8254
# 9    0.8393
# Name: ADM_RATE, dtype: float64

# %%
# Creating a data frame for admission rate cost as ADRate
AdRatet = dt[['ADM_RATE','COST']].copy()

# %%
AdRatet.corr()
# Out:
#           ADM_RATE      COST
# ADM_RATE  1.000000 -0.301969
# COST     -0.301969  1.000000

# %%
# sHOWING THE CORRELATION BETWEEN ADMISSION RATE AND COLLEGE COST IN  A SCATEER PLOT.
plt.scatter(dt.ADM_RATE*100, dt.COST, s, color='y')
plt.title("Correlation Between Admission Rates and College Cost")
plt.xlabel("ADMISSION RATE")
plt.ylabel("COLLEGE COST")
plt.show()

# %% [markdown]
#  # 6) What is the correlation between SAT scores and admission rates? Are there any outliers?

# %%
# arranging the SAT average in ascending form 
# to find the outliers there is only one method which is a box plot.
dt.SAT_AVG.sort_values(ascending=True).head(10)
# Out:
# 825     564.0
# 2513    822.0
# 2514    825.0
# 2553    834.0
# 3491    843.0
# 3320    845.0
# 3321    845.0
# 3544    846.0
# 849     850.0
# 2465    851.0
# Name: SAT_AVG, dtype: float64

# %%
dt.ADM_RATE.sort_values(ascending=True).head(10)
# Out:
# 6065    0.0000
# 5188    0.0000
# 2960    0.0000
# 6610    0.0000
# 2964    0.0330
# 3953    0.0473
# 1549    0.0516
# 2291    0.0592
# 2112    0.0641
# 2222    0.0661
# Name: ADM_RATE, dtype: float64

# %%
sns.boxplot(dt.SAT_AVG)

# %% [markdown]
#  # 7) What colleges have the highest and lowest family income averages?

# %%
# clearing Nan vlues
dff = df[df['FAMINC'].notnull()]

#  PrivacySuppressed values should be cleard
dff = dff[dff['FAMINC'] != 'PrivacySuppressed']

# converting string into float
dff['FAMINC'] = dff['FAMINC'].astype(float)

dff = dff.sort_values('FAMINC')

# %%
dff[dff['FAMINC'] ==dff['FAMINC'].max()]
# Out:
#       UNITID   OPEID  OPEID6                                  INSTNM  \
# 2290  192040  274000    2740  Jewish Theological Seminary of America
#
#           CITY STABBR         ZIP  \
# 2290  New York     NY  10027-4649
#
#                                       ACCREDAGENCY       INSTURL  \
# 2290  Middle States Commission on Higher Education  www.jtsa.edu
#
#                                              NPCURL  \
# 2290  https://npc.collegeboard.org/student/app/jtsa
#
#                   ...               OMAWDP8_NOTFIRSTTIME_POOLED_SUPP  \
# 2290              ...                              PrivacySuppressed
#
#       OMENRUP_NOTFIRSTTIME_POOLED_SUPP  OMENRYP_FULLTIME_POOLED_SUPP  \
# 2290                 PrivacySuppressed                             0
#
#       OMENRAP_FULLTIME_POOLED_SUPP  OMAWDP8_FULLTIME_POOLED_SUPP  \
# 2290                        0.0455                        0.8295
#
#       OMENRUP_FULLTIME_POOLED_SUPP  OMENRYP_PARTTIME_POOLED_SUPP  \
# ...

# %%
dff[dc['FAMINC'] ==dff['FAMINC'].min()]
# Out:
#     UNITID    OPEID  OPEID6                              INSTNM        CITY  \
# 26  101471  3002500   30025  J F Ingram State Technical College  Deatsville
#
#    STABBR    ZIP                       ACCREDAGENCY       INSTURL  \
# 26     AL  36022  Council on Occupational Education  www.istc.edu
#
#                                              NPCURL  \
# 26  nces.ed.gov/ipeds/netpricecalculator/Npc_2.aspx
#
#                 ...               OMAWDP8_NOTFIRSTTIME_POOLED_SUPP  \
# 26              ...                              PrivacySuppressed
#
#     OMENRUP_NOTFIRSTTIME_POOLED_SUPP  OMENRYP_FULLTIME_POOLED_SUPP  \
# 26                 PrivacySuppressed                         0.004
#
#     OMENRAP_FULLTIME_POOLED_SUPP  OMAWDP8_FULLTIME_POOLED_SUPP  \
# 26                             0                        0.4279
#
#     OMENRUP_FULLTIME_POOLED_SUPP  OMENRYP_PARTTIME_POOLED_SUPP  \
# 26                        0.5681                        0.0097
#
# ...

# %%
dff= dt[['FAMINC', 'COST']].copy()

# %%
dff.corr()
# Out:
#       COST
# COST   1.0
